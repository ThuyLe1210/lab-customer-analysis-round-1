# %%
import pandas as pd

# %%
df1= pd.read_csv('files_for_lab/csv_files/file1.csv')
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2=pd.read_csv('files_for_lab/csv_files/file2.csv')
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3=pd.read_csv('files_for_lab/csv_files/file3.csv')
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df1.shape
# Out:
# (4008, 11)

# %%
df2.shape
# Out:
# (996, 11)

# %%
df3.shape
# Out:
# (7070, 11)

# %%
df1.columns = df1.columns.str.upper()
df1.columns
# Out:
# Index(['CUSTOMER', 'ST', 'GENDER', 'EDUCATION', 'CUSTOMER LIFETIME VALUE',
#        'INCOME', 'MONTHLY PREMIUM AUTO', 'NUMBER OF OPEN COMPLAINTS',
#        'POLICY TYPE', 'VEHICLE CLASS', 'TOTAL CLAIM AMOUNT'],
#       dtype='object')

# %%
df2.columns = [df2.columns[i].upper().replace(' ', '_') for i in range(len(df2.columns)) ]
df2.columns
# Out:
# Index(['CUSTOMER', 'ST', 'GENDER', 'EDUCATION', 'CUSTOMER_LIFETIME_VALUE',
#        'INCOME', 'MONTHLY_PREMIUM_AUTO', 'NUMBER_OF_OPEN_COMPLAINTS',
#        'TOTAL_CLAIM_AMOUNT', 'POLICY_TYPE', 'VEHICLE_CLASS'],
#       dtype='object')

# %%
df3.columns = [df3.columns[i].upper().replace(' ', '_') for i in range(len(df3.columns)) ]
df3.columns
# Out:
# Index(['CUSTOMER', 'STATE', 'CUSTOMER_LIFETIME_VALUE', 'EDUCATION', 'GENDER',
#        'INCOME', 'MONTHLY_PREMIUM_AUTO', 'NUMBER_OF_OPEN_COMPLAINTS',
#        'POLICY_TYPE', 'TOTAL_CLAIM_AMOUNT', 'VEHICLE_CLASS'],
#       dtype='object')

# %%
import numpy as np

# %%
cols1 = list(df1.columns)
cols1.reverse()
cols1
# Out:
# ['Total Claim Amount',
#  'Vehicle Class',
#  'Policy Type',
#  'Number of Open Complaints',
#  'Monthly Premium Auto',
#  'Income',
#  'Customer Lifetime Value',
#  'Education',
#  'GENDER',
#  'ST',
#  'Customer']

# %%
df1[['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
       'Income','Vehicle Class', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type' , 'Total Claim Amount']]
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Vehicle Class  Monthly Premium Auto  \
# 0                        NaN      0.0  Four-Door Car                1000.0
# 1                 697953.59%      0.0  Four-Door Car                  94.0
# 2                1288743.17%  48767.0   Two-Door Car                 108.0
# ...

# %%
df1.columns
df2.columns
df3.columns
# Out:
# Index(['CUSTOMER', 'STATE', 'CUSTOMER_LIFETIME_VALUE', 'EDUCATION', 'GENDER',
#        'INCOME', 'MONTHLY_PREMIUM_AUTO', 'NUMBER_OF_OPEN_COMPLAINTS',
#        'POLICY_TYPE', 'TOTAL_CLAIM_AMOUNT', 'VEHICLE_CLASS'],
#       dtype='object')

# %%
pd.concat([df1, df2, df3])
# Out:
#      CUSTOMER          ST GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#      CUSTOMER LIFETIME VALUE   INCOME  MONTHLY PREMIUM AUTO  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df1.select_dtypes([np.number]).columns
df2.select_dtypes([np.number]).columns
df3.select_dtypes([np.number]).columns
# Out:
# Index(['CUSTOMER_LIFETIME_VALUE', 'INCOME', 'MONTHLY_PREMIUM_AUTO',
#        'NUMBER_OF_OPEN_COMPLAINTS', 'TOTAL_CLAIM_AMOUNT'],
#       dtype='object')

# %%
df1.select_dtypes(include='object').columns
# Out:
# Index(['CUSTOMER', 'ST', 'GENDER', 'EDUCATION', 'CUSTOMER LIFETIME VALUE',
#        'NUMBER OF OPEN COMPLAINTS', 'POLICY TYPE', 'VEHICLE CLASS'],
#       dtype='object')

# %%
df2.select_dtypes(include='object').columns
# Out:
# Index(['CUSTOMER', 'ST', 'GENDER', 'EDUCATION', 'CUSTOMER_LIFETIME_VALUE',
#        'NUMBER_OF_OPEN_COMPLAINTS', 'POLICY_TYPE', 'VEHICLE_CLASS'],
#       dtype='object')

# %%
df3.select_dtypes(include='object').columns
# Out:
# Index(['CUSTOMER', 'STATE', 'EDUCATION', 'GENDER', 'POLICY_TYPE',
#        'VEHICLE_CLASS'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['CUSTOMER', 'ST', 'GENDER', 'CUSTOMER LIFETIME VALUE', 'INCOME',
#        'MONTHLY PREMIUM AUTO', 'NUMBER OF OPEN COMPLAINTS', 'POLICY TYPE',
#        'VEHICLE CLASS', 'TOTAL CLAIM AMOUNT'],
#       dtype='object')

# %%
df1
# Out:
#      CUSTOMER          ST GENDER CUSTOMER LIFETIME VALUE   INCOME  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 4003      NaN         NaN    NaN                     NaN      NaN
# 4004      NaN         NaN    NaN                     NaN      NaN
# 4005      NaN         NaN    NaN                     NaN      NaN
# 4006      NaN         NaN    NaN                     NaN      NaN
# 4007      NaN         NaN    NaN                     NaN      NaN
#
#       MONTHLY PREMIUM AUTO NUMBER OF OPEN COMPLAINTS     POLICY TYPE  \
# 0                   1000.0                    1/0/00   Personal Auto
# ...

# %%
df1.drop('NUMBER OF OPEN COMPLAINTS', axis=1, inplace=True)
df1
# Out:
#      CUSTOMER          ST GENDER CUSTOMER LIFETIME VALUE   INCOME  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 4003      NaN         NaN    NaN                     NaN      NaN
# 4004      NaN         NaN    NaN                     NaN      NaN
# 4005      NaN         NaN    NaN                     NaN      NaN
# 4006      NaN         NaN    NaN                     NaN      NaN
# 4007      NaN         NaN    NaN                     NaN      NaN
#
#       MONTHLY PREMIUM AUTO     POLICY TYPE  VEHICLE CLASS  TOTAL CLAIM AMOUNT
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
df1['CUSTOMER LIFETIME VALUE'].str.rstrip("%").astype(float)*100
# Out:
# 0               NaN
# 1        69795359.0
# 2       128874317.0
# 3        76458618.0
# 4        53630765.0
#            ...
# 4003            NaN
# 4004            NaN
# 4005            NaN
# 4006            NaN
# 4007            NaN
# Name: CUSTOMER LIFETIME VALUE, Length: 4008, dtype: float64

# %%
 df1.drop_duplicates()
# Out:
#      CUSTOMER          ST GENDER CUSTOMER LIFETIME VALUE   INCOME  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 1067  VJ51327        Cali      F             2031499.76%  63209.0
# 1068  GS98873     Arizona      F              323912.47%  16061.0
# 1069  CW49887  California      F              462680.11%  79487.0
# 1070  MY31220  California      F              899704.02%  54230.0
# 1071      NaN         NaN    NaN                     NaN      NaN
#
#       MONTHLY PREMIUM AUTO     POLICY TYPE  VEHICLE CLASS  TOTAL CLAIM AMOUNT
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
df1.loc[df1['INCOME'] <= 0]
# Out:
#      CUSTOMER          ST GENDER CUSTOMER LIFETIME VALUE  INCOME  \
# 0     RB50392  Washington    NaN                     NaN     0.0
# 1     QZ44356     Arizona      F              697953.59%     0.0
# 3     WW63253  California      M              764586.18%     0.0
# 7     CF85061     Arizona      M              721610.03%     0.0
# 10    SX51350  California      M              473899.20%     0.0
# ...       ...         ...    ...                     ...     ...
# 1046  RG30482      Oregon      F             1366835.53%     0.0
# 1048  QQ39596     Arizona      F              251753.36%     0.0
# 1055  KJ86296      Oregon      M              455659.30%     0.0
# 1058  UX92071      Oregon      M              674311.93%     0.0
# 1061  RY92647        Cali      F             1050677.17%     0.0
#
#       MONTHLY PREMIUM AUTO     POLICY TYPE  VEHICLE CLASS  TOTAL CLAIM AMOUNT
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...
